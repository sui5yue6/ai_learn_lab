# %%
import torch
import torch.nn as nn

# %%
# 定义数据
input = torch.randn(3, 5)
target = torch.randn(3, 5)
print(input)
print(target)
# Out:
# tensor([[-1.0338,  0.8555,  0.2507,  0.3194, -1.6753],
#         [ 1.0962, -1.1339,  0.6823, -0.6814,  1.4190],
#         [ 0.1166,  0.5807, -0.5954, -1.4755, -0.0395]])
# tensor([[ 0.9562,  0.3249, -0.8963,  0.6248,  1.3624],
#         [-0.6692, -0.6318,  0.5881, -1.8051, -1.7873],
#         [-0.5757, -0.4550, -0.1805, -0.0764,  0.1652]])

# %%
# MSE: L2 Loss
mse_loss = nn.MSELoss()
print(mse_loss(input, target))
# Out:
# tensor(2.2347)

# %%
# MAE: L1 Loss
mse_loss = nn.L1Loss()
print(mse_loss(input, target))
# Out:
# tensor(1.1633)

# %%
# Smooth L1
smooth_l1_loss = nn.SmoothL1Loss()
print(smooth_l1_loss(input, target))
# Out:
# tensor(0.7579)
