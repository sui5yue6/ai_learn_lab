# %%
import torch

# %%
x = torch.randn(3, 5)
print(x)
# Out:
# tensor([[-1.1262,  0.1427, -0.0659, -2.2623,  2.3582],
#         [-0.2914, -2.1892,  0.7472,  1.6007,  1.0074],
#         [ 0.0841, -0.6847,  0.3112,  1.2761, -0.0645]])

# %%
y = torch.softmax(x, dim=1)
print(y)
# Out:
# tensor([[0.0248, 0.0881, 0.0715, 0.0080, 0.8076],
#         [0.0701, 0.0105, 0.1979, 0.4647, 0.2568],
#         [0.1455, 0.0674, 0.1826, 0.4791, 0.1254]])
