# %%
import torch

# %%
x = torch.tensor(2.0, requires_grad=True)
y = x.detach()
print(x)
print(y)
# Out:
# tensor(2., requires_grad=True)
# tensor(2.)

# %%
print(x.requires_grad)
print(y.requires_grad)
# Out:
# True
# False

# %%
print(id(x))
print(id(y))
# Out:
# 2296922302544
# 2296206649584

# %%
print(x.untyped_storage().data_ptr())
print(y.untyped_storage().data_ptr())
# Out:
# 5318146790720
# 5318146790720

# %%
# print(x)
# y.zero_()
# print(x)

# %%
# 分别对x、y进行后续计算
z1 = x ** 2
z2 = y ** 2
print(z1)
print(z2)
# Out:
# tensor(4., grad_fn=<PowBackward0>)
# tensor(4.)

# %%
print(z1.requires_grad)
print(z2.requires_grad)
# Out:
# True
# False

# %%
z1.sum().backward()

# %%
# z2.sum().backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 z2.sum().backward()
#
# File D:\Tools\anaconda3\envs\pytorch-2.6.0-gpu\Lib\site-packages\torch\_tensor.py:648, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     638 if has_torch_function_unary(self):
#     639     return handle_torch_function(
#     640         Tensor.backward,
#     641         (self,),
#    (...)    646         inputs=inputs,
#     647     )
# --> 648 torch.autograd.backward(
#     649     self, gradient, retain_graph, create_graph, inputs=inputs
#     650 )
#
# File D:\Tools\anaconda3\envs\pytorch-2.6.0-gpu\Lib\site-packages\torch\autograd\__init__.py:353, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     348     retain_graph = create_graph
#     350 # The reason we repeat the same comment below is that
#     351 # some Python versions print out the first line of a multi-line function
#     352 # calls in the traceback and some print out the last line
# --> 353 _engine_run_backward(
#     354     tensors,
#     355     grad_tensors_,
#     356     retain_graph,
#     357     create_graph,
#     358     inputs,
#     359     allow_unreachable=True,
#     360     accumulate_grad=True,
#     361 )
#
# File D:\Tools\anaconda3\envs\pytorch-2.6.0-gpu\Lib\site-packages\torch\autograd\graph.py:824, in _engine_run_backward(t_outputs, *args, **kwargs)
#     822     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     823 try:
# --> 824     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     825         t_outputs, *args, **kwargs
#     826     )  # Calls into the C++ engine to run the backward pass
#     827 finally:
#     828     if attach_logging_hooks:
#
# RuntimeError: element 0 of tensors does not require grad and does not have a grad_fn

# %%
x = torch.ones(2, 2, requires_grad=True)
y = x * x
print(x)
print(y)
# Out:
# tensor([[1., 1.],
#         [1., 1.]], requires_grad=True)
# tensor([[1., 1.],
#         [1., 1.]], grad_fn=<MulBackward0>)

# %%
# 分离y
u = y.detach()
print(u)
# Out:
# tensor([[1., 1.],
#         [1., 1.]])

# %%
# 让u参与新张量的计算
z = u * x

# %%
# 反向传播，计算所有梯度
z.sum().backward()

# %%
print(x.grad)
# Out:
# tensor([[1., 1.],
#         [1., 1.]])

# %%
print(x.grad == u)
# Out:
# tensor([[True, True],
#         [True, True]])
